# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Cargar los datos (ajusta el path de tu archivo)
df_clima = pd.read_csv('../data/processed/produccion_simulada_eolica.csv')

# Mostrar las primeras filas para inspección
print(df_clima.head())

# Verificar los tipos de datos de cada columna
print(df_clima.dtypes)

# Si hay columnas categóricas (como 'dir'), las codificamos
from sklearn.preprocessing import LabelEncoder

# Codificar la columna 'dir' (dirección del viento) si existe
if 'dir' in df_clima.columns:
    label_encoder = LabelEncoder()
    df_clima['dir_encoded'] = label_encoder.fit_transform(df_clima['dir'])
    print(f"Column 'dir' codificada:\n{df_clima[['dir', 'dir_encoded']].head()}")

# Seleccionar solo las columnas numéricas
df_clima.select_dtypes(include=['float64', 'int64']).fillna(df_clima.mean(), inplace=True)


# Calcular la matriz de correlación solo para columnas numéricas
correlation_matrix = df_numeric.corr()

# Mostrar la matriz de correlación
print(correlation_matrix)

# Visualizar la matriz de correlación con un heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Matriz de Correlación')
plt.show()

# Verificar si hay valores nulos y tratarlos
print(df_clima.isnull().sum())

# Ejemplo de tratamiento de valores nulos: llenar con la media
df_clima.fillna(df_clima.mean(), inplace=True)

# Verificar nuevamente si quedan valores nulos
print(df_clima.isnull().sum())
# Out:
#     Año  Mes  Día  Temp Media  Temp Máxima  Hora Temp Max  Minuto Temp Max  \
# 0  2016    1    1        10.3         11.2             20               40
# 1  2016    1    2        11.8         18.1             19               30
# 2  2016    1    3        11.3         16.4             15                0
# 3  2016    1    4        12.5         18.6             15               20
# 4  2016    1    5        12.0         18.8             15               15
#
#    Temp Mínima  Hora Temp Min  Minuto Temp Min  ...  Radiación Máxima  \
# 0          9.2              1               30  ...             256.0
# 1          8.6              0               55  ...             798.0
# 2          5.6              5               40  ...            1186.0
# 3          6.1              2               50  ...            1096.0
# 4          6.1             23               55  ...            1055.0
#
#   Hora Radiación Máxima  Minuto Radiación Mínima UV Máximo  Hora UV Máximo  \
# ...

# %%
# Verificar los tipos de datos de cada columna
print(df_clima.dtypes)
# Out:
# Año                          int64
# Mes                          int64
# Día                          int64
# Temp Media                 float64
# Temp Máxima                float64
# Hora Temp Max                int64
# Minuto Temp Max              int64
# Temp Mínima                float64
# Hora Temp Min                int64
# Minuto Temp Min              int64
# Viento Medio               float64
# Dirección Viento            object
# Ráfaga de Viento           float64
# Dirección de Ráfaga         object
# Hora Viento                  int64
# Minuto Viento                int64
# Presión Media              float64
# Lluvia Diaria              float64
# Radiación Máxima           float64
# Hora Radiación Máxima        int64
# Minuto Radiación Mínima      int64
# UV Máximo                  float64
# Hora UV Máximo               int64
# Minuto UV Máximo             int64
# factor_capacidad           float64
# produccion_diaria_MWh      float64
# Fecha_str                   object
# ...
